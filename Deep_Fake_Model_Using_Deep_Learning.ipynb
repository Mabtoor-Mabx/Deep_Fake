# %% [markdown]
# # **Deep Fake Model By Using First Order Motion Model for Image Animation**
#
# **--------------------------------------------------------------------------------------------------------------------------------------------------------**
#
# **In This Notebook, We try to create Deep Fake of Some Celebraties. For This Purpose, we Used `First Order Model Motion for Image Animation`.**
#
# **First Order Motion Model  paper : https://aliaksandrsiarohin.github.io/first-order-model-website/**
#
# **Referrence Code : https://github.com/AliaksandrSiarohin/first-order-model**
#
# **Note: This Deep Fake Model is Used for Education Purpose Only.**
#
#
#
# **For More Details :**
#
#
#
# **Github Link : https://github.com/Mabtoor-Mabx**
#
# **Linkedin Link : https://linkedin.com/in/mabtoor-mabx**

# %% [markdown]
# # **1-Clone Repository**
#
# **We Used `AliaksandrSiarohin` Github Repository to Import useful function that is helpful for deep fake model**

# %%
# !pip install PyYAML==5.3.1

# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# fatal: destination path 'first-order-model' already exists and is not an empty directory.

# %% [markdown]
# # **2-Change The Directory To First Order Model**

# %%
cd first-order-model
# Out:
# /content/first-order-model

# %% [markdown]
# # **3-Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **4-Load driving video and source image**

# %%
pip install imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

source_image = imageio.imread('/content/gdrive/MyDrive/first-order-motion-model/images (62).jpg')
driving_video = imageio.mimread('/content/gdrive/MyDrive/first-order-motion-model/zee_converted.mp4')
#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]

driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # **5-Create a model and load checkpoints**

# %%
from demo import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='/content/gdrive/MyDrive/vox-cpk.pth.tar')

# %% [markdown]
# # **6-Perform image animation**

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#save resulting video
imageio.mimsave('../generated.mp4', [img_as_ubyte(frame) for frame in predictions])
#video can be downloaded from /content folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 497/497 [00:21<00:00, 23.21it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
